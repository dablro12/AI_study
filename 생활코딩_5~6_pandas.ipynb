# %% [markdown]
# Reference Github : https://github.com/blackdew/tensorflow1

# %%
import pandas as pd

CSV_PATH = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/'
data_dir = {
    'lemonade' : 'lemonade.csv',
    'boston' : 'boston.csv',
    'iris' : 'iris.csv'
}
data_path = {
    'lemonade' : CSV_PATH + data_dir['lemonade'],
    'boston' : CSV_PATH + data_dir['boston'],
    'iris' : CSV_PATH + data_dir['iris']
}
# Out:
# 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/iris.csv'

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#데이터 불러오기
lemonade_df = pd.read_csv(data_path['lemonade'],)
boston_df = pd.read_csv(data_path['boston'], )
iris_df = pd.read_csv(data_path['iris'],)

# %%
#데이터프레임 모양 및 형태 확인
print(f'lemonade_df shape : {lemonade_df.shape}')
lemonade_df
# Out:
# lemonade_df shape : (6, 2)
#    온도  판매량
# 0  20   40
# 1  21   42
# 2  22   44
# 3  23   46
# 4  24   48
# 5  25   50

# %%
#칼럼이름 출력 df.columns
lemonade_df.columns
# Out:
# Index(['온도', '판매량'], dtype='object')

# %%
#독립변수 / 종속변수 나눠주기 : 레몬에이드 독립변수 : '온도', 종속변수 : '판매량'
x = lemonade_df[['온도']]
y = lemonade_df[['판매량']]

# %%
#위에 다섯개 출력해보기
head = lemonade_df.head(5)
tail = lemonade_df.tail(5)

head
# Out:
#    온도  판매량
# 0  20   40
# 1  21   42
# 2  22   44
# 3  23   46
# 4  24   48
